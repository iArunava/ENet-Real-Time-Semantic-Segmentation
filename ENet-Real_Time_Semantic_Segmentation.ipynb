# %% [markdown]
# # ENet -  Real Time Semantic Segmentation
#
# In this notebook, we have reproduced the ENet paper. <br/>
# Link to the paper: https://arxiv.org/pdf/1606.02147.pdf <br/>
# Link to the repository: https://github.com/iArunava/ENet-Real-Time-Semantic-Segmentation
#
#
# Star and Fork!
#
#
# **ALL THE CODE IN THIS NOTEBOOK ASSUMES THE USAGE OF THE <span style="color:blue;">CAMVID</span> DATASET**

# %% [markdown]
# ## Install the dependencies and Import them

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import matplotlib.pyplot as plt
from torch.optim.lr_scheduler import StepLR
import cv2
import os
from tqdm import tqdm
from PIL import Image

# %% [markdown]
# ## Download the CamVid dataset

# %%
# !wget https://www.dropbox.com/s/pxcz2wdz04zxocq/CamVid.zip?dl=1 -O CamVid.zip
# !unzip CamVid.zip
# Out:
# --2019-02-11 05:49:11--  https://www.dropbox.com/s/pxcz2wdz04zxocq/CamVid.zip?dl=1
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.8.1, 2620:100:601b:1::a27d:801
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.8.1|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/dl/pxcz2wdz04zxocq/CamVid.zip [following]
# --2019-02-11 05:49:12--  https://www.dropbox.com/s/dl/pxcz2wdz04zxocq/CamVid.zip
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc8efa962e60080f671a9160e4c3.dl.dropboxusercontent.com/cd/0/get/AbGprN-EM-eEB0fCOM-NNckeht8IOYx-9whmIlz3GojHn1gO0Mq-_WZF0Kq7WuJaFXJlWEEDFuK-hQqyn5v1EziN3kiZso7VSqSefq9LOrgd0Q/file?dl=1# [following]
# --2019-02-11 05:49:12--  https://uc8efa962e60080f671a9160e4c3.dl.dropboxusercontent.com/cd/0/get/AbGprN-EM-eEB0fCOM-NNckeht8IOYx-9whmIlz3GojHn1gO0Mq-_WZF0Kq7WuJaFXJlWEEDFuK-hQqyn5v1EziN3kiZso7VSqSefq9LOrgd0Q/file?dl=1
# Resolving uc8efa962e60080f671a9160e4c3.dl.dropboxusercontent.com (uc8efa962e60080f671a9160e4c3.dl.dropboxusercontent.com)... 162.125.8.6, 2620:100:6018:6::a27d:306
# Connecting to uc8efa962e60080f671a9160e4c3.dl.dropboxusercontent.com (uc8efa962e60080f671a9160e4c3.dl.dropboxusercontent.com)|162.125.8.6|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 187049523 (178M) [application/binary]
# Saving to: ‘CamVid.zip’
#
# CamVid.zip          100%[===================>] 178.38M  50.9MB/s    in 3.5s
#
# 2019-02-11 05:49:16 (50.9 MB/s) - ‘CamVid.zip’ saved [187049523/187049523]
#
# Archive:  CamVid.zip
#    creating: test/
#   inflating: test/0001TP_008550.png
#   inflating: test/0001TP_008580.png
#   inflating: test/0001TP_008610.png
#   inflating: test/0001TP_008640.png
#   inflating: test/0001TP_008670.png
#   inflating: test/0001TP_008700.png
#   inflating: test/0001TP_008730.png
#   inflating: test/0001TP_008760.png
#   inflating: test/0001TP_008790.png
#   inflating: test/0001TP_008820.png
#   inflating: test/0001TP_008850.png
#   inflating: test/0001TP_008880.png
#   inflating: test/0001TP_008910.png
#   inflating: test/0001TP_008940.png
#   inflating: test/0001TP_008970.png
#   inflating: test/0001TP_009000.png
#   inflating: test/0001TP_009030.png
#   inflating: test/0001TP_009060.png
#   inflating: test/0001TP_009090.png
#   inflating: test/0001TP_009120.png
#   inflating: test/0001TP_009150.png
#   inflating: test/0001TP_009180.png
#   inflating: test/0001TP_009210.png
#   inflating: test/0001TP_009240.png
#   inflating: test/0001TP_009270.png
#   inflating: test/0001TP_009300.png
#   inflating: test/0001TP_009330.png
#   inflating: test/0001TP_009360.png
#   inflating: test/0001TP_009390.png
#   inflating: test/0001TP_009420.png
#   inflating: test/0001TP_009450.png
#   inflating: test/0001TP_009480.png
#   inflating: test/0001TP_009510.png
#   inflating: test/0001TP_009540.png
#   inflating: test/0001TP_009570.png
#   inflating: test/0001TP_009600.png
#   inflating: test/0001TP_009630.png
#   inflating: test/0001TP_009660.png
#   inflating: test/0001TP_009690.png
#   inflating: test/0001TP_009720.png
#   inflating: test/0001TP_009750.png
#   inflating: test/0001TP_009780.png
#   inflating: test/0001TP_009810.png
#   inflating: test/0001TP_009840.png
#   inflating: test/0001TP_009870.png
#   inflating: test/0001TP_009900.png
#   inflating: test/0001TP_009930.png
#   inflating: test/0001TP_009960.png
#   inflating: test/0001TP_009990.png
#   inflating: test/0001TP_010020.png
#   inflating: test/0001TP_010050.png
#   inflating: test/0001TP_010080.png
#   inflating: test/0001TP_010110.png
#   inflating: test/0001TP_010140.png
#   inflating: test/0001TP_010170.png
#   inflating: test/0001TP_010200.png
#   inflating: test/0001TP_010230.png
#   inflating: test/0001TP_010260.png
#   inflating: test/0001TP_010290.png
#   inflating: test/0001TP_010320.png
#   inflating: test/0001TP_010350.png
#   inflating: test/0001TP_010380.png
#   inflating: test/Seq05VD_f00000.png
#   inflating: test/Seq05VD_f00030.png
#   inflating: test/Seq05VD_f00060.png
#   inflating: test/Seq05VD_f00090.png
#   inflating: test/Seq05VD_f00120.png
#   inflating: test/Seq05VD_f00150.png
#   inflating: test/Seq05VD_f00180.png
#   inflating: test/Seq05VD_f00210.png
#   inflating: test/Seq05VD_f00240.png
#   inflating: test/Seq05VD_f00270.png
#   inflating: test/Seq05VD_f00300.png
#   inflating: test/Seq05VD_f00330.png
#   inflating: test/Seq05VD_f00360.png
#   inflating: test/Seq05VD_f00390.png
#   inflating: test/Seq05VD_f00420.png
#   inflating: test/Seq05VD_f00450.png
#   inflating: test/Seq05VD_f00480.png
#   inflating: test/Seq05VD_f00510.png
#   inflating: test/Seq05VD_f00540.png
#   inflating: test/Seq05VD_f00570.png
#   inflating: test/Seq05VD_f00600.png
#   inflating: test/Seq05VD_f00630.png
#   inflating: test/Seq05VD_f00660.png
#   inflating: test/Seq05VD_f00690.png
#   inflating: test/Seq05VD_f00720.png
#   inflating: test/Seq05VD_f00750.png
#   inflating: test/Seq05VD_f00780.png
#   inflating: test/Seq05VD_f00810.png
#   inflating: test/Seq05VD_f00840.png
#   inflating: test/Seq05VD_f00870.png
#   inflating: test/Seq05VD_f00900.png
#   inflating: test/Seq05VD_f00930.png
#   inflating: test/Seq05VD_f00960.png
#   inflating: test/Seq05VD_f00990.png
#   inflating: test/Seq05VD_f01020.png
#   inflating: test/Seq05VD_f01050.png
#   inflating: test/Seq05VD_f01080.png
#   inflating: test/Seq05VD_f01110.png
#   inflating: test/Seq05VD_f01140.png
#   inflating: test/Seq05VD_f01170.png
#   inflating: test/Seq05VD_f01200.png
#   inflating: test/Seq05VD_f01230.png
#   inflating: test/Seq05VD_f01260.png
#   inflating: test/Seq05VD_f01290.png
#   inflating: test/Seq05VD_f01320.png
#   inflating: test/Seq05VD_f01350.png
#   inflating: test/Seq05VD_f01380.png
#   inflating: test/Seq05VD_f01410.png
#   inflating: test/Seq05VD_f01440.png
#   inflating: test/Seq05VD_f01470.png
#   inflating: test/Seq05VD_f01500.png
#   inflating: test/Seq05VD_f01530.png
#   inflating: test/Seq05VD_f01560.png
#   inflating: test/Seq05VD_f01590.png
#   inflating: test/Seq05VD_f01620.png
#   inflating: test/Seq05VD_f01650.png
#   inflating: test/Seq05VD_f01680.png
#   inflating: test/Seq05VD_f01710.png
#   inflating: test/Seq05VD_f01740.png
#   inflating: test/Seq05VD_f01770.png
#   inflating: test/Seq05VD_f01800.png
#   inflating: test/Seq05VD_f01830.png
#   inflating: test/Seq05VD_f01860.png
#   inflating: test/Seq05VD_f01890.png
#   inflating: test/Seq05VD_f01920.png
#   inflating: test/Seq05VD_f01950.png
#   inflating: test/Seq05VD_f01980.png
#   inflating: test/Seq05VD_f02010.png
#   inflating: test/Seq05VD_f02040.png
#   inflating: test/Seq05VD_f02070.png
#   inflating: test/Seq05VD_f02100.png
#   inflating: test/Seq05VD_f02130.png
#   inflating: test/Seq05VD_f02160.png
#   inflating: test/Seq05VD_f02190.png
#   inflating: test/Seq05VD_f02220.png
#   inflating: test/Seq05VD_f02250.png
#   inflating: test/Seq05VD_f02280.png
#   inflating: test/Seq05VD_f02310.png
#   inflating: test/Seq05VD_f02340.png
#   inflating: test/Seq05VD_f02370.png
#   inflating: test/Seq05VD_f02400.png
#   inflating: test/Seq05VD_f02430.png
#   inflating: test/Seq05VD_f02460.png
#   inflating: test/Seq05VD_f02490.png
#   inflating: test/Seq05VD_f02520.png
#   inflating: test/Seq05VD_f02550.png
#   inflating: test/Seq05VD_f02580.png
#   inflating: test/Seq05VD_f02610.png
#   inflating: test/Seq05VD_f02640.png
#   inflating: test/Seq05VD_f02670.png
#   inflating: test/Seq05VD_f02700.png
#   inflating: test/Seq05VD_f02730.png
#   inflating: test/Seq05VD_f02760.png
#   inflating: test/Seq05VD_f02790.png
#   inflating: test/Seq05VD_f02820.png
#   inflating: test/Seq05VD_f02850.png
#   inflating: test/Seq05VD_f02880.png
#   inflating: test/Seq05VD_f02910.png
#   inflating: test/Seq05VD_f02940.png
#   inflating: test/Seq05VD_f02970.png
#   inflating: test/Seq05VD_f03000.png
#   inflating: test/Seq05VD_f03030.png
#   inflating: test/Seq05VD_f03060.png
#   inflating: test/Seq05VD_f03090.png
#   inflating: test/Seq05VD_f03120.png
#   inflating: test/Seq05VD_f03150.png
#   inflating: test/Seq05VD_f03180.png
#   inflating: test/Seq05VD_f03210.png
#   inflating: test/Seq05VD_f03240.png
#   inflating: test/Seq05VD_f03270.png
#   inflating: test/Seq05VD_f03300.png
#   inflating: test/Seq05VD_f03330.png
#   inflating: test/Seq05VD_f03360.png
#   inflating: test/Seq05VD_f03390.png
#   inflating: test/Seq05VD_f03420.png
#   inflating: test/Seq05VD_f03450.png
#   inflating: test/Seq05VD_f03480.png
#   inflating: test/Seq05VD_f03510.png
#   inflating: test/Seq05VD_f03540.png
#   inflating: test/Seq05VD_f03570.png
#   inflating: test/Seq05VD_f03600.png
#   inflating: test/Seq05VD_f03630.png
#   inflating: test/Seq05VD_f03660.png
#   inflating: test/Seq05VD_f03690.png
#   inflating: test/Seq05VD_f03720.png
#   inflating: test/Seq05VD_f03750.png
#   inflating: test/Seq05VD_f03780.png
#   inflating: test/Seq05VD_f03810.png
#   inflating: test/Seq05VD_f03840.png
#   inflating: test/Seq05VD_f03870.png
#   inflating: test/Seq05VD_f03900.png
#   inflating: test/Seq05VD_f03930.png
#   inflating: test/Seq05VD_f03960.png
#   inflating: test/Seq05VD_f03990.png
#   inflating: test/Seq05VD_f04020.png
#   inflating: test/Seq05VD_f04050.png
#   inflating: test/Seq05VD_f04080.png
#   inflating: test/Seq05VD_f04110.png
#   inflating: test/Seq05VD_f04140.png
#   inflating: test/Seq05VD_f04170.png
#   inflating: test/Seq05VD_f04200.png
#   inflating: test/Seq05VD_f04230.png
#   inflating: test/Seq05VD_f04260.png
#   inflating: test/Seq05VD_f04290.png
#   inflating: test/Seq05VD_f04320.png
#   inflating: test/Seq05VD_f04350.png
#   inflating: test/Seq05VD_f04380.png
#   inflating: test/Seq05VD_f04410.png
#   inflating: test/Seq05VD_f04440.png
#   inflating: test/Seq05VD_f04470.png
#   inflating: test/Seq05VD_f04500.png
#   inflating: test/Seq05VD_f04530.png
#   inflating: test/Seq05VD_f04560.png
#   inflating: test/Seq05VD_f04590.png
#   inflating: test/Seq05VD_f04620.png
#   inflating: test/Seq05VD_f04650.png
#   inflating: test/Seq05VD_f04680.png
#   inflating: test/Seq05VD_f04710.png
#   inflating: test/Seq05VD_f04740.png
#   inflating: test/Seq05VD_f04770.png
#   inflating: test/Seq05VD_f04800.png
#   inflating: test/Seq05VD_f04830.png
#   inflating: test/Seq05VD_f04860.png
#   inflating: test/Seq05VD_f04890.png
#   inflating: test/Seq05VD_f04920.png
#   inflating: test/Seq05VD_f04950.png
#   inflating: test/Seq05VD_f04980.png
#   inflating: test/Seq05VD_f05010.png
#   inflating: test/Seq05VD_f05040.png
#   inflating: test/Seq05VD_f05070.png
#   inflating: test/Seq05VD_f05100.png
#    creating: testannot/
#   inflating: testannot/0001TP_008550.png
#   inflating: testannot/0001TP_008580.png
#   inflating: testannot/0001TP_008610.png
#   inflating: testannot/0001TP_008640.png
#   inflating: testannot/0001TP_008670.png
#   inflating: testannot/0001TP_008700.png
#   inflating: testannot/0001TP_008730.png
#   inflating: testannot/0001TP_008760.png
#   inflating: testannot/0001TP_008790.png
#   inflating: testannot/0001TP_008820.png
#   inflating: testannot/0001TP_008850.png
#   inflating: testannot/0001TP_008880.png
#   inflating: testannot/0001TP_008910.png
#   inflating: testannot/0001TP_008940.png
#   inflating: testannot/0001TP_008970.png
#   inflating: testannot/0001TP_009000.png
#   inflating: testannot/0001TP_009030.png
#   inflating: testannot/0001TP_009060.png
#   inflating: testannot/0001TP_009090.png
#   inflating: testannot/0001TP_009120.png
#   inflating: testannot/0001TP_009150.png
#   inflating: testannot/0001TP_009180.png
#   inflating: testannot/0001TP_009210.png
#   inflating: testannot/0001TP_009240.png
#   inflating: testannot/0001TP_009270.png
#   inflating: testannot/0001TP_009300.png
#   inflating: testannot/0001TP_009330.png
#   inflating: testannot/0001TP_009360.png
#   inflating: testannot/0001TP_009390.png
#   inflating: testannot/0001TP_009420.png
#   inflating: testannot/0001TP_009450.png
#   inflating: testannot/0001TP_009480.png
#   inflating: testannot/0001TP_009510.png
#   inflating: testannot/0001TP_009540.png
#   inflating: testannot/0001TP_009570.png
#   inflating: testannot/0001TP_009600.png
#   inflating: testannot/0001TP_009630.png
#   inflating: testannot/0001TP_009660.png
#   inflating: testannot/0001TP_009690.png
#   inflating: testannot/0001TP_009720.png
#   inflating: testannot/0001TP_009750.png
#   inflating: testannot/0001TP_009780.png
#   inflating: testannot/0001TP_009810.png
#   inflating: testannot/0001TP_009840.png
#   inflating: testannot/0001TP_009870.png
#   inflating: testannot/0001TP_009900.png
#   inflating: testannot/0001TP_009930.png
#   inflating: testannot/0001TP_009960.png
#   inflating: testannot/0001TP_009990.png
#   inflating: testannot/0001TP_010020.png
#   inflating: testannot/0001TP_010050.png
#   inflating: testannot/0001TP_010080.png
#   inflating: testannot/0001TP_010110.png
#   inflating: testannot/0001TP_010140.png
#   inflating: testannot/0001TP_010170.png
#   inflating: testannot/0001TP_010200.png
#   inflating: testannot/0001TP_010230.png
#   inflating: testannot/0001TP_010260.png
#   inflating: testannot/0001TP_010290.png
#   inflating: testannot/0001TP_010320.png
#   inflating: testannot/0001TP_010350.png
#   inflating: testannot/0001TP_010380.png
#   inflating: testannot/Seq05VD_f00000.png
#   inflating: testannot/Seq05VD_f00030.png
#   inflating: testannot/Seq05VD_f00060.png
#   inflating: testannot/Seq05VD_f00090.png
#   inflating: testannot/Seq05VD_f00120.png
#   inflating: testannot/Seq05VD_f00150.png
#   inflating: testannot/Seq05VD_f00180.png
#   inflating: testannot/Seq05VD_f00210.png
#   inflating: testannot/Seq05VD_f00240.png
#   inflating: testannot/Seq05VD_f00270.png
#   inflating: testannot/Seq05VD_f00300.png
#   inflating: testannot/Seq05VD_f00330.png
#   inflating: testannot/Seq05VD_f00360.png
#   inflating: testannot/Seq05VD_f00390.png
#   inflating: testannot/Seq05VD_f00420.png
#   inflating: testannot/Seq05VD_f00450.png
#   inflating: testannot/Seq05VD_f00480.png
#   inflating: testannot/Seq05VD_f00510.png
#   inflating: testannot/Seq05VD_f00540.png
#   inflating: testannot/Seq05VD_f00570.png
#   inflating: testannot/Seq05VD_f00600.png
#   inflating: testannot/Seq05VD_f00630.png
#   inflating: testannot/Seq05VD_f00660.png
#   inflating: testannot/Seq05VD_f00690.png
#   inflating: testannot/Seq05VD_f00720.png
#   inflating: testannot/Seq05VD_f00750.png
#   inflating: testannot/Seq05VD_f00780.png
#   inflating: testannot/Seq05VD_f00810.png
#   inflating: testannot/Seq05VD_f00840.png
#   inflating: testannot/Seq05VD_f00870.png
#   inflating: testannot/Seq05VD_f00900.png
#   inflating: testannot/Seq05VD_f00930.png
#   inflating: testannot/Seq05VD_f00960.png
#   inflating: testannot/Seq05VD_f00990.png
#   inflating: testannot/Seq05VD_f01020.png
#   inflating: testannot/Seq05VD_f01050.png
#   inflating: testannot/Seq05VD_f01080.png
#   inflating: testannot/Seq05VD_f01110.png
#   inflating: testannot/Seq05VD_f01140.png
#   inflating: testannot/Seq05VD_f01170.png
#   inflating: testannot/Seq05VD_f01200.png
#   inflating: testannot/Seq05VD_f01230.png
#   inflating: testannot/Seq05VD_f01260.png
#   inflating: testannot/Seq05VD_f01290.png
#   inflating: testannot/Seq05VD_f01320.png
#   inflating: testannot/Seq05VD_f01350.png
#   inflating: testannot/Seq05VD_f01380.png
#   inflating: testannot/Seq05VD_f01410.png
#   inflating: testannot/Seq05VD_f01440.png
#   inflating: testannot/Seq05VD_f01470.png
#   inflating: testannot/Seq05VD_f01500.png
#   inflating: testannot/Seq05VD_f01530.png
#   inflating: testannot/Seq05VD_f01560.png
#   inflating: testannot/Seq05VD_f01590.png
#   inflating: testannot/Seq05VD_f01620.png
#   inflating: testannot/Seq05VD_f01650.png
#   inflating: testannot/Seq05VD_f01680.png
#   inflating: testannot/Seq05VD_f01710.png
#   inflating: testannot/Seq05VD_f01740.png
#   inflating: testannot/Seq05VD_f01770.png
#   inflating: testannot/Seq05VD_f01800.png
#   inflating: testannot/Seq05VD_f01830.png
#   inflating: testannot/Seq05VD_f01860.png
#   inflating: testannot/Seq05VD_f01890.png
#   inflating: testannot/Seq05VD_f01920.png
#   inflating: testannot/Seq05VD_f01950.png
#   inflating: testannot/Seq05VD_f01980.png
#   inflating: testannot/Seq05VD_f02010.png
#   inflating: testannot/Seq05VD_f02040.png
#   inflating: testannot/Seq05VD_f02070.png
#   inflating: testannot/Seq05VD_f02100.png
#   inflating: testannot/Seq05VD_f02130.png
#   inflating: testannot/Seq05VD_f02160.png
#   inflating: testannot/Seq05VD_f02190.png
#   inflating: testannot/Seq05VD_f02220.png
#   inflating: testannot/Seq05VD_f02250.png
#   inflating: testannot/Seq05VD_f02280.png
#   inflating: testannot/Seq05VD_f02310.png
#   inflating: testannot/Seq05VD_f02340.png
#   inflating: testannot/Seq05VD_f02370.png
#   inflating: testannot/Seq05VD_f02400.png
#   inflating: testannot/Seq05VD_f02430.png
#   inflating: testannot/Seq05VD_f02460.png
#   inflating: testannot/Seq05VD_f02490.png
#   inflating: testannot/Seq05VD_f02520.png
#   inflating: testannot/Seq05VD_f02550.png
#   inflating: testannot/Seq05VD_f02580.png
#   inflating: testannot/Seq05VD_f02610.png
#   inflating: testannot/Seq05VD_f02640.png
#   inflating: testannot/Seq05VD_f02670.png
#   inflating: testannot/Seq05VD_f02700.png
#   inflating: testannot/Seq05VD_f02730.png
#   inflating: testannot/Seq05VD_f02760.png
#   inflating: testannot/Seq05VD_f02790.png
#   inflating: testannot/Seq05VD_f02820.png
#   inflating: testannot/Seq05VD_f02850.png
#   inflating: testannot/Seq05VD_f02880.png
#   inflating: testannot/Seq05VD_f02910.png
#   inflating: testannot/Seq05VD_f02940.png
#   inflating: testannot/Seq05VD_f02970.png
#   inflating: testannot/Seq05VD_f03000.png
#   inflating: testannot/Seq05VD_f03030.png
#   inflating: testannot/Seq05VD_f03060.png
#   inflating: testannot/Seq05VD_f03090.png
#   inflating: testannot/Seq05VD_f03120.png
#   inflating: testannot/Seq05VD_f03150.png
#   inflating: testannot/Seq05VD_f03180.png
#   inflating: testannot/Seq05VD_f03210.png
#   inflating: testannot/Seq05VD_f03240.png
#   inflating: testannot/Seq05VD_f03270.png
#   inflating: testannot/Seq05VD_f03300.png
#   inflating: testannot/Seq05VD_f03330.png
#   inflating: testannot/Seq05VD_f03360.png
#   inflating: testannot/Seq05VD_f03390.png
#   inflating: testannot/Seq05VD_f03420.png
#   inflating: testannot/Seq05VD_f03450.png
#   inflating: testannot/Seq05VD_f03480.png
#   inflating: testannot/Seq05VD_f03510.png
#   inflating: testannot/Seq05VD_f03540.png
#   inflating: testannot/Seq05VD_f03570.png
#   inflating: testannot/Seq05VD_f03600.png
#   inflating: testannot/Seq05VD_f03630.png
#   inflating: testannot/Seq05VD_f03660.png
#   inflating: testannot/Seq05VD_f03690.png
#   inflating: testannot/Seq05VD_f03720.png
#   inflating: testannot/Seq05VD_f03750.png
#   inflating: testannot/Seq05VD_f03780.png
#   inflating: testannot/Seq05VD_f03810.png
#   inflating: testannot/Seq05VD_f03840.png
#   inflating: testannot/Seq05VD_f03870.png
#   inflating: testannot/Seq05VD_f03900.png
#   inflating: testannot/Seq05VD_f03930.png
#   inflating: testannot/Seq05VD_f03960.png
#   inflating: testannot/Seq05VD_f03990.png
#   inflating: testannot/Seq05VD_f04020.png
#   inflating: testannot/Seq05VD_f04050.png
#   inflating: testannot/Seq05VD_f04080.png
#   inflating: testannot/Seq05VD_f04110.png
#   inflating: testannot/Seq05VD_f04140.png
#   inflating: testannot/Seq05VD_f04170.png
#   inflating: testannot/Seq05VD_f04200.png
#   inflating: testannot/Seq05VD_f04230.png
#   inflating: testannot/Seq05VD_f04260.png
#   inflating: testannot/Seq05VD_f04290.png
#   inflating: testannot/Seq05VD_f04320.png
#   inflating: testannot/Seq05VD_f04350.png
#   inflating: testannot/Seq05VD_f04380.png
#   inflating: testannot/Seq05VD_f04410.png
#   inflating: testannot/Seq05VD_f04440.png
#   inflating: testannot/Seq05VD_f04470.png
#   inflating: testannot/Seq05VD_f04500.png
#   inflating: testannot/Seq05VD_f04530.png
#   inflating: testannot/Seq05VD_f04560.png
#   inflating: testannot/Seq05VD_f04590.png
#   inflating: testannot/Seq05VD_f04620.png
#   inflating: testannot/Seq05VD_f04650.png
#   inflating: testannot/Seq05VD_f04680.png
#   inflating: testannot/Seq05VD_f04710.png
#   inflating: testannot/Seq05VD_f04740.png
#   inflating: testannot/Seq05VD_f04770.png
#   inflating: testannot/Seq05VD_f04800.png
#   inflating: testannot/Seq05VD_f04830.png
#   inflating: testannot/Seq05VD_f04860.png
#   inflating: testannot/Seq05VD_f04890.png
#   inflating: testannot/Seq05VD_f04920.png
#   inflating: testannot/Seq05VD_f04950.png
#   inflating: testannot/Seq05VD_f04980.png
#   inflating: testannot/Seq05VD_f05010.png
#   inflating: testannot/Seq05VD_f05040.png
#   inflating: testannot/Seq05VD_f05070.png
#   inflating: testannot/Seq05VD_f05100.png
#    creating: train/
#   inflating: train/0001TP_006690.png
#   inflating: train/0001TP_006720.png
#   inflating: train/0001TP_006750.png
#   inflating: train/0001TP_006780.png
#   inflating: train/0001TP_006810.png
#   inflating: train/0001TP_006840.png
#   inflating: train/0001TP_006870.png
#   inflating: train/0001TP_006900.png
#   inflating: train/0001TP_006930.png
#   inflating: train/0001TP_006960.png
#   inflating: train/0001TP_006990.png
#   inflating: train/0001TP_007020.png
#   inflating: train/0001TP_007050.png
#   inflating: train/0001TP_007080.png
#   inflating: train/0001TP_007110.png
#   inflating: train/0001TP_007140.png
#   inflating: train/0001TP_007170.png
#   inflating: train/0001TP_007200.png
#   inflating: train/0001TP_007230.png
#   inflating: train/0001TP_007260.png
#   inflating: train/0001TP_007290.png
#   inflating: train/0001TP_007320.png
#   inflating: train/0001TP_007350.png
#   inflating: train/0001TP_007380.png
#   inflating: train/0001TP_007410.png
#   inflating: train/0001TP_007440.png
#   inflating: train/0001TP_007470.png
#   inflating: train/0001TP_007500.png
#   inflating: train/0001TP_007530.png
#   inflating: train/0001TP_007560.png
#   inflating: train/0001TP_007590.png
#   inflating: train/0001TP_007620.png
#   inflating: train/0001TP_007650.png
#   inflating: train/0001TP_007680.png
#   inflating: train/0001TP_007710.png
#   inflating: train/0001TP_007740.png
#   inflating: train/0001TP_007770.png
#   inflating: train/0001TP_007800.png
#   inflating: train/0001TP_007830.png
#   inflating: train/0001TP_007860.png
#   inflating: train/0001TP_007890.png
#   inflating: train/0001TP_007920.png
#   inflating: train/0001TP_007950.png
#   inflating: train/0001TP_007980.png
#   inflating: train/0001TP_008010.png
#   inflating: train/0001TP_008040.png
#   inflating: train/0001TP_008070.png
#   inflating: train/0001TP_008100.png
#   inflating: train/0001TP_008130.png
#   inflating: train/0001TP_008160.png
#   inflating: train/0001TP_008190.png
#   inflating: train/0001TP_008220.png
#   inflating: train/0001TP_008250.png
#   inflating: train/0001TP_008280.png
#   inflating: train/0001TP_008310.png
#   inflating: train/0001TP_008340.png
#   inflating: train/0001TP_008370.png
#   inflating: train/0001TP_008400.png
#   inflating: train/0001TP_008430.png
#   inflating: train/0001TP_008460.png
#   inflating: train/0001TP_008490.png
#   inflating: train/0001TP_008520.png
#   inflating: train/0006R0_f00930.png
#   inflating: train/0006R0_f00960.png
#   inflating: train/0006R0_f00990.png
#   inflating: train/0006R0_f01020.png
#   inflating: train/0006R0_f01050.png
#   inflating: train/0006R0_f01080.png
#   inflating: train/0006R0_f01110.png
#   inflating: train/0006R0_f01140.png
#   inflating: train/0006R0_f01170.png
#   inflating: train/0006R0_f01200.png
#   inflating: train/0006R0_f01230.png
#   inflating: train/0006R0_f01260.png
#   inflating: train/0006R0_f01290.png
#   inflating: train/0006R0_f01320.png
#   inflating: train/0006R0_f01350.png
#   inflating: train/0006R0_f01380.png
#   inflating: train/0006R0_f01410.png
#   inflating: train/0006R0_f01440.png
#   inflating: train/0006R0_f01470.png
#   inflating: train/0006R0_f01500.png
#   inflating: train/0006R0_f01530.png
#   inflating: train/0006R0_f01560.png
#   inflating: train/0006R0_f01590.png
#   inflating: train/0006R0_f01620.png
#   inflating: train/0006R0_f01650.png
#   inflating: train/0006R0_f01680.png
#   inflating: train/0006R0_f01710.png
#   inflating: train/0006R0_f01740.png
#   inflating: train/0006R0_f01770.png
#   inflating: train/0006R0_f01800.png
#   inflating: train/0006R0_f01830.png
#   inflating: train/0006R0_f01860.png
#   inflating: train/0006R0_f01890.png
#   inflating: train/0006R0_f01920.png
#   inflating: train/0006R0_f01950.png
#   inflating: train/0006R0_f01980.png
#   inflating: train/0006R0_f02010.png
#   inflating: train/0006R0_f02040.png
#   inflating: train/0006R0_f02070.png
#   inflating: train/0006R0_f02100.png
#   inflating: train/0006R0_f02130.png
#   inflating: train/0006R0_f02160.png
#   inflating: train/0006R0_f02190.png
#   inflating: train/0006R0_f02220.png
#   inflating: train/0006R0_f02250.png
#   inflating: train/0006R0_f02280.png
#   inflating: train/0006R0_f02310.png
#   inflating: train/0006R0_f02340.png
#   inflating: train/0006R0_f02370.png
#   inflating: train/0006R0_f02400.png
#   inflating: train/0006R0_f02430.png
#   inflating: train/0006R0_f02460.png
#   inflating: train/0006R0_f02490.png
#   inflating: train/0006R0_f02520.png
#   inflating: train/0006R0_f02550.png
#   inflating: train/0006R0_f02580.png
#   inflating: train/0006R0_f02610.png
#   inflating: train/0006R0_f02640.png
#   inflating: train/0006R0_f02670.png
#   inflating: train/0006R0_f02700.png
#   inflating: train/0006R0_f02730.png
#   inflating: train/0006R0_f02760.png
#   inflating: train/0006R0_f02790.png
#   inflating: train/0006R0_f02820.png
#   inflating: train/0006R0_f02850.png
#   inflating: train/0006R0_f02880.png
#   inflating: train/0006R0_f02910.png
#   inflating: train/0006R0_f02940.png
#   inflating: train/0006R0_f02970.png
#   inflating: train/0006R0_f03000.png
#   inflating: train/0006R0_f03030.png
#   inflating: train/0006R0_f03060.png
#   inflating: train/0006R0_f03090.png
#   inflating: train/0006R0_f03120.png
#   inflating: train/0006R0_f03150.png
#   inflating: train/0006R0_f03180.png
#   inflating: train/0006R0_f03210.png
#   inflating: train/0006R0_f03240.png
#   inflating: train/0006R0_f03270.png
#   inflating: train/0006R0_f03300.png
#   inflating: train/0006R0_f03330.png
#   inflating: train/0006R0_f03360.png
#   inflating: train/0006R0_f03390.png
#   inflating: train/0006R0_f03420.png
#   inflating: train/0006R0_f03450.png
#   inflating: train/0006R0_f03480.png
#   inflating: train/0006R0_f03510.png
#   inflating: train/0006R0_f03540.png
#   inflating: train/0006R0_f03570.png
#   inflating: train/0006R0_f03600.png
#   inflating: train/0006R0_f03630.png
#   inflating: train/0006R0_f03660.png
#   inflating: train/0006R0_f03690.png
#   inflating: train/0006R0_f03720.png
#   inflating: train/0006R0_f03750.png
#   inflating: train/0006R0_f03780.png
#   inflating: train/0006R0_f03810.png
#   inflating: train/0006R0_f03840.png
#   inflating: train/0006R0_f03870.png
#   inflating: train/0006R0_f03900.png
#   inflating: train/0006R0_f03930.png
#   inflating: train/0016E5_00390.png
#   inflating: train/0016E5_00420.png
#   inflating: train/0016E5_00450.png
#   inflating: train/0016E5_00480.png
#   inflating: train/0016E5_00510.png
#   inflating: train/0016E5_00540.png
#   inflating: train/0016E5_00570.png
#   inflating: train/0016E5_00600.png
#   inflating: train/0016E5_00630.png
#   inflating: train/0016E5_00660.png
#   inflating: train/0016E5_00690.png
#   inflating: train/0016E5_00720.png
#   inflating: train/0016E5_00750.png
#   inflating: train/0016E5_00780.png
#   inflating: train/0016E5_00810.png
#   inflating: train/0016E5_00840.png
#   inflating: train/0016E5_00870.png
#   inflating: train/0016E5_00901.png
#   inflating: train/0016E5_00930.png
#   inflating: train/0016E5_00960.png
#   inflating: train/0016E5_00990.png
#   inflating: train/0016E5_01020.png
#   inflating: train/0016E5_01050.png
#   inflating: train/0016E5_01080.png
#   inflating: train/0016E5_01110.png
#   inflating: train/0016E5_01140.png
#   inflating: train/0016E5_01170.png
#   inflating: train/0016E5_01200.png
#   inflating: train/0016E5_01230.png
#   inflating: train/0016E5_01260.png
#   inflating: train/0016E5_01290.png
#   inflating: train/0016E5_01320.png
#   inflating: train/0016E5_01350.png
#   inflating: train/0016E5_01380.png
#   inflating: train/0016E5_01410.png
#   inflating: train/0016E5_01440.png
#   inflating: train/0016E5_01470.png
#   inflating: train/0016E5_01500.png
#   inflating: train/0016E5_01530.png
#   inflating: train/0016E5_01560.png
#   inflating: train/0016E5_01590.png
#   inflating: train/0016E5_01620.png
#   inflating: train/0016E5_01650.png
#   inflating: train/0016E5_01680.png
#   inflating: train/0016E5_01710.png
#   inflating: train/0016E5_01740.png
#   inflating: train/0016E5_01770.png
#   inflating: train/0016E5_01800.png
#   inflating: train/0016E5_01830.png
#   inflating: train/0016E5_01860.png
#   inflating: train/0016E5_01890.png
#   inflating: train/0016E5_01920.png
#   inflating: train/0016E5_01950.png
#   inflating: train/0016E5_01980.png
#   inflating: train/0016E5_02010.png
#   inflating: train/0016E5_02040.png
#   inflating: train/0016E5_02070.png
#   inflating: train/0016E5_02100.png
#   inflating: train/0016E5_02130.png
#   inflating: train/0016E5_02160.png
#   inflating: train/0016E5_02190.png
#   inflating: train/0016E5_02220.png
#   inflating: train/0016E5_02250.png
#   inflating: train/0016E5_02280.png
#   inflating: train/0016E5_02310.png
#   inflating: train/0016E5_02340.png
#   inflating: train/0016E5_02370.png
#   inflating: train/0016E5_02400.png
#   inflating: train/0016E5_04350.png
#   inflating: train/0016E5_04380.png
#   inflating: train/0016E5_04410.png
#   inflating: train/0016E5_04440.png
#   inflating: train/0016E5_04470.png
#   inflating: train/0016E5_04500.png
#   inflating: train/0016E5_04530.png
#   inflating: train/0016E5_04560.png
#   inflating: train/0016E5_04590.png
#   inflating: train/0016E5_04620.png
#   inflating: train/0016E5_04650.png
#   inflating: train/0016E5_04680.png
#   inflating: train/0016E5_04710.png
#   inflating: train/0016E5_04740.png
#   inflating: train/0016E5_04770.png
#   inflating: train/0016E5_04800.png
#   inflating: train/0016E5_04830.png
#   inflating: train/0016E5_04860.png
#   inflating: train/0016E5_04890.png
#   inflating: train/0016E5_04920.png
#   inflating: train/0016E5_04950.png
#   inflating: train/0016E5_04980.png
#   inflating: train/0016E5_05010.png
#   inflating: train/0016E5_05040.png
#   inflating: train/0016E5_05070.png
#   inflating: train/0016E5_05100.png
#   inflating: train/0016E5_05130.png
#   inflating: train/0016E5_05160.png
#   inflating: train/0016E5_05190.png
#   inflating: train/0016E5_05220.png
#   inflating: train/0016E5_05250.png
#   inflating: train/0016E5_05280.png
#   inflating: train/0016E5_05310.png
#   inflating: train/0016E5_05340.png
#   inflating: train/0016E5_05370.png
#   inflating: train/0016E5_05400.png
#   inflating: train/0016E5_05430.png
#   inflating: train/0016E5_05460.png
#   inflating: train/0016E5_05490.png
#   inflating: train/0016E5_05520.png
#   inflating: train/0016E5_05550.png
#   inflating: train/0016E5_05580.png
#   inflating: train/0016E5_05610.png
#   inflating: train/0016E5_05640.png
#   inflating: train/0016E5_05670.png
#   inflating: train/0016E5_05700.png
#   inflating: train/0016E5_05730.png
#   inflating: train/0016E5_05760.png
#   inflating: train/0016E5_05790.png
#   inflating: train/0016E5_05820.png
#   inflating: train/0016E5_05850.png
#   inflating: train/0016E5_05880.png
#   inflating: train/0016E5_05910.png
#   inflating: train/0016E5_05940.png
#   inflating: train/0016E5_05970.png
#   inflating: train/0016E5_06000.png
#   inflating: train/0016E5_06030.png
#   inflating: train/0016E5_06060.png
#   inflating: train/0016E5_06090.png
#   inflating: train/0016E5_06120.png
#   inflating: train/0016E5_06150.png
#   inflating: train/0016E5_06180.png
#   inflating: train/0016E5_06210.png
#   inflating: train/0016E5_06240.png
#   inflating: train/0016E5_06270.png
#   inflating: train/0016E5_06300.png
#   inflating: train/0016E5_06330.png
#   inflating: train/0016E5_06360.png
#   inflating: train/0016E5_06390.png
#   inflating: train/0016E5_06420.png
#   inflating: train/0016E5_06450.png
#   inflating: train/0016E5_06480.png
#   inflating: train/0016E5_06510.png
#   inflating: train/0016E5_06540.png
#   inflating: train/0016E5_06570.png
#   inflating: train/0016E5_06600.png
#   inflating: train/0016E5_06630.png
#   inflating: train/0016E5_06660.png
#   inflating: train/0016E5_06690.png
#   inflating: train/0016E5_06720.png
#   inflating: train/0016E5_06750.png
#   inflating: train/0016E5_06780.png
#   inflating: train/0016E5_06810.png
#   inflating: train/0016E5_06840.png
#   inflating: train/0016E5_06870.png
#   inflating: train/0016E5_06900.png
#   inflating: train/0016E5_06930.png
#   inflating: train/0016E5_06960.png
#   inflating: train/0016E5_06990.png
#   inflating: train/0016E5_07020.png
#   inflating: train/0016E5_07050.png
#   inflating: train/0016E5_07080.png
#   inflating: train/0016E5_07110.png
#   inflating: train/0016E5_07140.png
#   inflating: train/0016E5_07170.png
#   inflating: train/0016E5_07200.png
#   inflating: train/0016E5_07230.png
#   inflating: train/0016E5_07260.png
#   inflating: train/0016E5_07290.png
#   inflating: train/0016E5_07320.png
#   inflating: train/0016E5_07350.png
#   inflating: train/0016E5_07380.png
#   inflating: train/0016E5_07410.png
#   inflating: train/0016E5_07440.png
#   inflating: train/0016E5_07470.png
#   inflating: train/0016E5_07500.png
#   inflating: train/0016E5_07530.png
#   inflating: train/0016E5_07560.png
#   inflating: train/0016E5_07590.png
#   inflating: train/0016E5_07620.png
#   inflating: train/0016E5_07650.png
#   inflating: train/0016E5_07680.png
#   inflating: train/0016E5_07710.png
#   inflating: train/0016E5_07740.png
#   inflating: train/0016E5_07770.png
#   inflating: train/0016E5_07800.png
#   inflating: train/0016E5_07830.png
#   inflating: train/0016E5_07860.png
#   inflating: train/0016E5_07890.png
#   inflating: train/0016E5_07920.png
#   inflating: train/0016E5_08190.png
#   inflating: train/0016E5_08220.png
#   inflating: train/0016E5_08250.png
#   inflating: train/0016E5_08280.png
#   inflating: train/0016E5_08310.png
#   inflating: train/0016E5_08340.png
#   inflating: train/0016E5_08370.png
#   inflating: train/0016E5_08400.png
#   inflating: train/0016E5_08430.png
#   inflating: train/0016E5_08460.png
#   inflating: train/0016E5_08490.png
#   inflating: train/0016E5_08520.png
#   inflating: train/0016E5_08550.png
#   inflating: train/0016E5_08580.png
#   inflating: train/0016E5_08610.png
#   inflating: train/0016E5_08640.png
#    creating: trainannot/
#   inflating: trainannot/0001TP_006690.png
#   inflating: trainannot/0001TP_006720.png
#   inflating: trainannot/0001TP_006750.png
#   inflating: trainannot/0001TP_006780.png
#   inflating: trainannot/0001TP_006810.png
#   inflating: trainannot/0001TP_006840.png
#   inflating: trainannot/0001TP_006870.png
#   inflating: trainannot/0001TP_006900.png
#   inflating: trainannot/0001TP_006930.png
#   inflating: trainannot/0001TP_006960.png
#   inflating: trainannot/0001TP_006990.png
#   inflating: trainannot/0001TP_007020.png
#   inflating: trainannot/0001TP_007050.png
#   inflating: trainannot/0001TP_007080.png
#   inflating: trainannot/0001TP_007110.png
#   inflating: trainannot/0001TP_007140.png
#   inflating: trainannot/0001TP_007170.png
#   inflating: trainannot/0001TP_007200.png
#   inflating: trainannot/0001TP_007230.png
#   inflating: trainannot/0001TP_007260.png
#   inflating: trainannot/0001TP_007290.png
#   inflating: trainannot/0001TP_007320.png
#   inflating: trainannot/0001TP_007350.png
#   inflating: trainannot/0001TP_007380.png
#   inflating: trainannot/0001TP_007410.png
#   inflating: trainannot/0001TP_007440.png
#   inflating: trainannot/0001TP_007470.png
#   inflating: trainannot/0001TP_007500.png
#   inflating: trainannot/0001TP_007530.png
#   inflating: trainannot/0001TP_007560.png
#   inflating: trainannot/0001TP_007590.png
#   inflating: trainannot/0001TP_007620.png
#   inflating: trainannot/0001TP_007650.png
#   inflating: trainannot/0001TP_007680.png
#   inflating: trainannot/0001TP_007710.png
#   inflating: trainannot/0001TP_007740.png
#   inflating: trainannot/0001TP_007770.png
#   inflating: trainannot/0001TP_007800.png
#   inflating: trainannot/0001TP_007830.png
#   inflating: trainannot/0001TP_007860.png
#   inflating: trainannot/0001TP_007890.png
#   inflating: trainannot/0001TP_007920.png
#   inflating: trainannot/0001TP_007950.png
#   inflating: trainannot/0001TP_007980.png
#   inflating: trainannot/0001TP_008010.png
#   inflating: trainannot/0001TP_008040.png
#   inflating: trainannot/0001TP_008070.png
#   inflating: trainannot/0001TP_008100.png
#   inflating: trainannot/0001TP_008130.png
#   inflating: trainannot/0001TP_008160.png
#   inflating: trainannot/0001TP_008190.png
#   inflating: trainannot/0001TP_008220.png
#   inflating: trainannot/0001TP_008250.png
#   inflating: trainannot/0001TP_008280.png
#   inflating: trainannot/0001TP_008310.png
#   inflating: trainannot/0001TP_008340.png
#   inflating: trainannot/0001TP_008370.png
#   inflating: trainannot/0001TP_008400.png
#   inflating: trainannot/0001TP_008430.png
#   inflating: trainannot/0001TP_008460.png
#   inflating: trainannot/0001TP_008490.png
#   inflating: trainannot/0001TP_008520.png
#   inflating: trainannot/0006R0_f00930.png
#   inflating: trainannot/0006R0_f00960.png
#   inflating: trainannot/0006R0_f00990.png
#   inflating: trainannot/0006R0_f01020.png
#   inflating: trainannot/0006R0_f01050.png
#   inflating: trainannot/0006R0_f01080.png
#   inflating: trainannot/0006R0_f01110.png
#   inflating: trainannot/0006R0_f01140.png
#   inflating: trainannot/0006R0_f01170.png
#   inflating: trainannot/0006R0_f01200.png
#   inflating: trainannot/0006R0_f01230.png
#   inflating: trainannot/0006R0_f01260.png
#   inflating: trainannot/0006R0_f01290.png
#   inflating: trainannot/0006R0_f01320.png
#   inflating: trainannot/0006R0_f01350.png
#   inflating: trainannot/0006R0_f01380.png
#   inflating: trainannot/0006R0_f01410.png
#   inflating: trainannot/0006R0_f01440.png
#   inflating: trainannot/0006R0_f01470.png
#   inflating: trainannot/0006R0_f01500.png
#   inflating: trainannot/0006R0_f01530.png
#   inflating: trainannot/0006R0_f01560.png
#   inflating: trainannot/0006R0_f01590.png
#   inflating: trainannot/0006R0_f01620.png
#   inflating: trainannot/0006R0_f01650.png
#   inflating: trainannot/0006R0_f01680.png
#   inflating: trainannot/0006R0_f01710.png
#   inflating: trainannot/0006R0_f01740.png
#   inflating: trainannot/0006R0_f01770.png
#   inflating: trainannot/0006R0_f01800.png
#   inflating: trainannot/0006R0_f01830.png
#   inflating: trainannot/0006R0_f01860.png
#   inflating: trainannot/0006R0_f01890.png
#   inflating: trainannot/0006R0_f01920.png
#   inflating: trainannot/0006R0_f01950.png
#   inflating: trainannot/0006R0_f01980.png
#   inflating: trainannot/0006R0_f02010.png
#   inflating: trainannot/0006R0_f02040.png
#   inflating: trainannot/0006R0_f02070.png
#   inflating: trainannot/0006R0_f02100.png
#   inflating: trainannot/0006R0_f02130.png
#   inflating: trainannot/0006R0_f02160.png
#   inflating: trainannot/0006R0_f02190.png
#   inflating: trainannot/0006R0_f02220.png
#   inflating: trainannot/0006R0_f02250.png
#   inflating: trainannot/0006R0_f02280.png
#   inflating: trainannot/0006R0_f02310.png
#   inflating: trainannot/0006R0_f02340.png
#   inflating: trainannot/0006R0_f02370.png
#   inflating: trainannot/0006R0_f02400.png
#   inflating: trainannot/0006R0_f02430.png
#   inflating: trainannot/0006R0_f02460.png
#   inflating: trainannot/0006R0_f02490.png
#   inflating: trainannot/0006R0_f02520.png
#   inflating: trainannot/0006R0_f02550.png
#   inflating: trainannot/0006R0_f02580.png
#   inflating: trainannot/0006R0_f02610.png
#   inflating: trainannot/0006R0_f02640.png
#   inflating: trainannot/0006R0_f02670.png
#   inflating: trainannot/0006R0_f02700.png
#   inflating: trainannot/0006R0_f02730.png
#   inflating: trainannot/0006R0_f02760.png
#   inflating: trainannot/0006R0_f02790.png
#   inflating: trainannot/0006R0_f02820.png
#   inflating: trainannot/0006R0_f02850.png
#   inflating: trainannot/0006R0_f02880.png
#   inflating: trainannot/0006R0_f02910.png
#   inflating: trainannot/0006R0_f02940.png
#   inflating: trainannot/0006R0_f02970.png
#   inflating: trainannot/0006R0_f03000.png
#   inflating: trainannot/0006R0_f03030.png
#   inflating: trainannot/0006R0_f03060.png
#   inflating: trainannot/0006R0_f03090.png
#   inflating: trainannot/0006R0_f03120.png
#   inflating: trainannot/0006R0_f03150.png
#   inflating: trainannot/0006R0_f03180.png
#   inflating: trainannot/0006R0_f03210.png
#   inflating: trainannot/0006R0_f03240.png
#   inflating: trainannot/0006R0_f03270.png
#   inflating: trainannot/0006R0_f03300.png
#   inflating: trainannot/0006R0_f03330.png
#   inflating: trainannot/0006R0_f03360.png
#   inflating: trainannot/0006R0_f03390.png
#   inflating: trainannot/0006R0_f03420.png
#   inflating: trainannot/0006R0_f03450.png
#   inflating: trainannot/0006R0_f03480.png
#   inflating: trainannot/0006R0_f03510.png
#   inflating: trainannot/0006R0_f03540.png
#   inflating: trainannot/0006R0_f03570.png
#   inflating: trainannot/0006R0_f03600.png
#   inflating: trainannot/0006R0_f03630.png
#   inflating: trainannot/0006R0_f03660.png
#   inflating: trainannot/0006R0_f03690.png
#   inflating: trainannot/0006R0_f03720.png
#   inflating: trainannot/0006R0_f03750.png
#   inflating: trainannot/0006R0_f03780.png
#   inflating: trainannot/0006R0_f03810.png
#   inflating: trainannot/0006R0_f03840.png
#   inflating: trainannot/0006R0_f03870.png
#   inflating: trainannot/0006R0_f03900.png
#   inflating: trainannot/0006R0_f03930.png
#   inflating: trainannot/0016E5_00390.png
#   inflating: trainannot/0016E5_00420.png
#   inflating: trainannot/0016E5_00450.png
#   inflating: trainannot/0016E5_00480.png
#   inflating: trainannot/0016E5_00510.png
#   inflating: trainannot/0016E5_00540.png
#   inflating: trainannot/0016E5_00570.png
#   inflating: trainannot/0016E5_00600.png
#   inflating: trainannot/0016E5_00630.png
#   inflating: trainannot/0016E5_00660.png
#   inflating: trainannot/0016E5_00690.png
#   inflating: trainannot/0016E5_00720.png
#   inflating: trainannot/0016E5_00750.png
#   inflating: trainannot/0016E5_00780.png
#   inflating: trainannot/0016E5_00810.png
#   inflating: trainannot/0016E5_00840.png
#   inflating: trainannot/0016E5_00870.png
#   inflating: trainannot/0016E5_00901.png
#   inflating: trainannot/0016E5_00930.png
#   inflating: trainannot/0016E5_00960.png
#   inflating: trainannot/0016E5_00990.png
#   inflating: trainannot/0016E5_01020.png
#   inflating: trainannot/0016E5_01050.png
#   inflating: trainannot/0016E5_01080.png
#   inflating: trainannot/0016E5_01110.png
#   inflating: trainannot/0016E5_01140.png
#   inflating: trainannot/0016E5_01170.png
#   inflating: trainannot/0016E5_01200.png
#   inflating: trainannot/0016E5_01230.png
#   inflating: trainannot/0016E5_01260.png
#   inflating: trainannot/0016E5_01290.png
#   inflating: trainannot/0016E5_01320.png
#   inflating: trainannot/0016E5_01350.png
#   inflating: trainannot/0016E5_01380.png
#   inflating: trainannot/0016E5_01410.png
#   inflating: trainannot/0016E5_01440.png
#   inflating: trainannot/0016E5_01470.png
#   inflating: trainannot/0016E5_01500.png
#   inflating: trainannot/0016E5_01530.png
#   inflating: trainannot/0016E5_01560.png
#   inflating: trainannot/0016E5_01590.png
#   inflating: trainannot/0016E5_01620.png
#   inflating: trainannot/0016E5_01650.png
#   inflating: trainannot/0016E5_01680.png
#   inflating: trainannot/0016E5_01710.png
#   inflating: trainannot/0016E5_01740.png
#   inflating: trainannot/0016E5_01770.png
#   inflating: trainannot/0016E5_01800.png
#   inflating: trainannot/0016E5_01830.png
#   inflating: trainannot/0016E5_01860.png
#   inflating: trainannot/0016E5_01890.png
#   inflating: trainannot/0016E5_01920.png
#   inflating: trainannot/0016E5_01950.png
#   inflating: trainannot/0016E5_01980.png
#   inflating: trainannot/0016E5_02010.png
#   inflating: trainannot/0016E5_02040.png
#   inflating: trainannot/0016E5_02070.png
#   inflating: trainannot/0016E5_02100.png
#   inflating: trainannot/0016E5_02130.png
#   inflating: trainannot/0016E5_02160.png
#   inflating: trainannot/0016E5_02190.png
#   inflating: trainannot/0016E5_02220.png
#   inflating: trainannot/0016E5_02250.png
#   inflating: trainannot/0016E5_02280.png
#   inflating: trainannot/0016E5_02310.png
#   inflating: trainannot/0016E5_02340.png
#   inflating: trainannot/0016E5_02370.png
#   inflating: trainannot/0016E5_02400.png
#   inflating: trainannot/0016E5_04350.png
#   inflating: trainannot/0016E5_04380.png
#   inflating: trainannot/0016E5_04410.png
#   inflating: trainannot/0016E5_04440.png
#   inflating: trainannot/0016E5_04470.png
#   inflating: trainannot/0016E5_04500.png
#   inflating: trainannot/0016E5_04530.png
#   inflating: trainannot/0016E5_04560.png
#   inflating: trainannot/0016E5_04590.png
#   inflating: trainannot/0016E5_04620.png
#   inflating: trainannot/0016E5_04650.png
#   inflating: trainannot/0016E5_04680.png
#   inflating: trainannot/0016E5_04710.png
#   inflating: trainannot/0016E5_04740.png
#   inflating: trainannot/0016E5_04770.png
#   inflating: trainannot/0016E5_04800.png
#   inflating: trainannot/0016E5_04830.png
#   inflating: trainannot/0016E5_04860.png
#   inflating: trainannot/0016E5_04890.png
#   inflating: trainannot/0016E5_04920.png
#   inflating: trainannot/0016E5_04950.png
#   inflating: trainannot/0016E5_04980.png
#   inflating: trainannot/0016E5_05010.png
#   inflating: trainannot/0016E5_05040.png
#   inflating: trainannot/0016E5_05070.png
#   inflating: trainannot/0016E5_05100.png
#   inflating: trainannot/0016E5_05130.png
#   inflating: trainannot/0016E5_05160.png
#   inflating: trainannot/0016E5_05190.png
#   inflating: trainannot/0016E5_05220.png
#   inflating: trainannot/0016E5_05250.png
#   inflating: trainannot/0016E5_05280.png
#   inflating: trainannot/0016E5_05310.png
#   inflating: trainannot/0016E5_05340.png
#   inflating: trainannot/0016E5_05370.png
#   inflating: trainannot/0016E5_05400.png
#   inflating: trainannot/0016E5_05430.png
#   inflating: trainannot/0016E5_05460.png
#   inflating: trainannot/0016E5_05490.png
#   inflating: trainannot/0016E5_05520.png
#   inflating: trainannot/0016E5_05550.png
#   inflating: trainannot/0016E5_05580.png
#   inflating: trainannot/0016E5_05610.png
#   inflating: trainannot/0016E5_05640.png
#   inflating: trainannot/0016E5_05670.png
#   inflating: trainannot/0016E5_05700.png
#   inflating: trainannot/0016E5_05730.png
#   inflating: trainannot/0016E5_05760.png
#   inflating: trainannot/0016E5_05790.png
#   inflating: trainannot/0016E5_05820.png
#   inflating: trainannot/0016E5_05850.png
#   inflating: trainannot/0016E5_05880.png
#   inflating: trainannot/0016E5_05910.png
#   inflating: trainannot/0016E5_05940.png
#   inflating: trainannot/0016E5_05970.png
#   inflating: trainannot/0016E5_06000.png
#   inflating: trainannot/0016E5_06030.png
#   inflating: trainannot/0016E5_06060.png
#   inflating: trainannot/0016E5_06090.png
#   inflating: trainannot/0016E5_06120.png
#   inflating: trainannot/0016E5_06150.png
#   inflating: trainannot/0016E5_06180.png
#   inflating: trainannot/0016E5_06210.png
#   inflating: trainannot/0016E5_06240.png
#   inflating: trainannot/0016E5_06270.png
#   inflating: trainannot/0016E5_06300.png
#   inflating: trainannot/0016E5_06330.png
#   inflating: trainannot/0016E5_06360.png
#   inflating: trainannot/0016E5_06390.png
#   inflating: trainannot/0016E5_06420.png
#   inflating: trainannot/0016E5_06450.png
#   inflating: trainannot/0016E5_06480.png
#   inflating: trainannot/0016E5_06510.png
#   inflating: trainannot/0016E5_06540.png
#   inflating: trainannot/0016E5_06570.png
#   inflating: trainannot/0016E5_06600.png
#   inflating: trainannot/0016E5_06630.png
#   inflating: trainannot/0016E5_06660.png
#   inflating: trainannot/0016E5_06690.png
#   inflating: trainannot/0016E5_06720.png
#   inflating: trainannot/0016E5_06750.png
#   inflating: trainannot/0016E5_06780.png
#   inflating: trainannot/0016E5_06810.png
#   inflating: trainannot/0016E5_06840.png
#   inflating: trainannot/0016E5_06870.png
#   inflating: trainannot/0016E5_06900.png
#   inflating: trainannot/0016E5_06930.png
#   inflating: trainannot/0016E5_06960.png
#   inflating: trainannot/0016E5_06990.png
#   inflating: trainannot/0016E5_07020.png
#   inflating: trainannot/0016E5_07050.png
#   inflating: trainannot/0016E5_07080.png
#   inflating: trainannot/0016E5_07110.png
#   inflating: trainannot/0016E5_07140.png
#   inflating: trainannot/0016E5_07170.png
#   inflating: trainannot/0016E5_07200.png
#   inflating: trainannot/0016E5_07230.png
#   inflating: trainannot/0016E5_07260.png
#   inflating: trainannot/0016E5_07290.png
#   inflating: trainannot/0016E5_07320.png
#   inflating: trainannot/0016E5_07350.png
#   inflating: trainannot/0016E5_07380.png
#   inflating: trainannot/0016E5_07410.png
#   inflating: trainannot/0016E5_07440.png
#   inflating: trainannot/0016E5_07470.png
#   inflating: trainannot/0016E5_07500.png
#   inflating: trainannot/0016E5_07530.png
#   inflating: trainannot/0016E5_07560.png
#   inflating: trainannot/0016E5_07590.png
#   inflating: trainannot/0016E5_07620.png
#   inflating: trainannot/0016E5_07650.png
#   inflating: trainannot/0016E5_07680.png
#   inflating: trainannot/0016E5_07710.png
#   inflating: trainannot/0016E5_07740.png
#   inflating: trainannot/0016E5_07770.png
#   inflating: trainannot/0016E5_07800.png
#   inflating: trainannot/0016E5_07830.png
#   inflating: trainannot/0016E5_07860.png
#   inflating: trainannot/0016E5_07890.png
#   inflating: trainannot/0016E5_07920.png
#   inflating: trainannot/0016E5_08190.png
#   inflating: trainannot/0016E5_08220.png
#   inflating: trainannot/0016E5_08250.png
#   inflating: trainannot/0016E5_08280.png
#   inflating: trainannot/0016E5_08310.png
#   inflating: trainannot/0016E5_08340.png
#   inflating: trainannot/0016E5_08370.png
#   inflating: trainannot/0016E5_08400.png
#   inflating: trainannot/0016E5_08430.png
#   inflating: trainannot/0016E5_08460.png
#   inflating: trainannot/0016E5_08490.png
#   inflating: trainannot/0016E5_08520.png
#   inflating: trainannot/0016E5_08550.png
#   inflating: trainannot/0016E5_08580.png
#   inflating: trainannot/0016E5_08610.png
#   inflating: trainannot/0016E5_08640.png
#    creating: val/
#   inflating: val/0016E5_07959.png
#   inflating: val/0016E5_07961.png
#   inflating: val/0016E5_07963.png
#   inflating: val/0016E5_07965.png
#   inflating: val/0016E5_07967.png
#   inflating: val/0016E5_07969.png
#   inflating: val/0016E5_07971.png
#   inflating: val/0016E5_07973.png
#   inflating: val/0016E5_07975.png
#   inflating: val/0016E5_07977.png
#   inflating: val/0016E5_07979.png
#   inflating: val/0016E5_07981.png
#   inflating: val/0016E5_07983.png
#   inflating: val/0016E5_07985.png
#   inflating: val/0016E5_07987.png
#   inflating: val/0016E5_07989.png
#   inflating: val/0016E5_07991.png
#   inflating: val/0016E5_07993.png
#   inflating: val/0016E5_07995.png
#   inflating: val/0016E5_07997.png
#   inflating: val/0016E5_07999.png
#   inflating: val/0016E5_08001.png
#   inflating: val/0016E5_08003.png
#   inflating: val/0016E5_08005.png
#   inflating: val/0016E5_08007.png
#   inflating: val/0016E5_08009.png
#   inflating: val/0016E5_08011.png
#   inflating: val/0016E5_08013.png
#   inflating: val/0016E5_08015.png
#   inflating: val/0016E5_08017.png
#   inflating: val/0016E5_08019.png
#   inflating: val/0016E5_08021.png
#   inflating: val/0016E5_08023.png
#   inflating: val/0016E5_08025.png
#   inflating: val/0016E5_08027.png
#   inflating: val/0016E5_08029.png
#   inflating: val/0016E5_08031.png
#   inflating: val/0016E5_08033.png
#   inflating: val/0016E5_08035.png
#   inflating: val/0016E5_08037.png
#   inflating: val/0016E5_08039.png
#   inflating: val/0016E5_08041.png
#   inflating: val/0016E5_08043.png
#   inflating: val/0016E5_08045.png
#   inflating: val/0016E5_08047.png
#   inflating: val/0016E5_08049.png
#   inflating: val/0016E5_08051.png
#   inflating: val/0016E5_08053.png
#   inflating: val/0016E5_08055.png
#   inflating: val/0016E5_08057.png
#   inflating: val/0016E5_08059.png
#   inflating: val/0016E5_08061.png
#   inflating: val/0016E5_08063.png
#   inflating: val/0016E5_08065.png
#   inflating: val/0016E5_08067.png
#   inflating: val/0016E5_08069.png
#   inflating: val/0016E5_08071.png
#   inflating: val/0016E5_08073.png
#   inflating: val/0016E5_08075.png
#   inflating: val/0016E5_08077.png
#   inflating: val/0016E5_08079.png
#   inflating: val/0016E5_08081.png
#   inflating: val/0016E5_08083.png
#   inflating: val/0016E5_08085.png
#   inflating: val/0016E5_08087.png
#   inflating: val/0016E5_08089.png
#   inflating: val/0016E5_08091.png
#   inflating: val/0016E5_08093.png
#   inflating: val/0016E5_08095.png
#   inflating: val/0016E5_08097.png
#   inflating: val/0016E5_08099.png
#   inflating: val/0016E5_08101.png
#   inflating: val/0016E5_08103.png
#   inflating: val/0016E5_08105.png
#   inflating: val/0016E5_08107.png
#   inflating: val/0016E5_08109.png
#   inflating: val/0016E5_08111.png
#   inflating: val/0016E5_08113.png
#   inflating: val/0016E5_08115.png
#   inflating: val/0016E5_08117.png
#   inflating: val/0016E5_08119.png
#   inflating: val/0016E5_08121.png
#   inflating: val/0016E5_08123.png
#   inflating: val/0016E5_08125.png
#   inflating: val/0016E5_08127.png
#   inflating: val/0016E5_08129.png
#   inflating: val/0016E5_08131.png
#   inflating: val/0016E5_08133.png
#   inflating: val/0016E5_08135.png
#   inflating: val/0016E5_08137.png
#   inflating: val/0016E5_08139.png
#   inflating: val/0016E5_08141.png
#   inflating: val/0016E5_08143.png
#   inflating: val/0016E5_08145.png
#   inflating: val/0016E5_08147.png
#   inflating: val/0016E5_08149.png
#   inflating: val/0016E5_08151.png
#   inflating: val/0016E5_08153.png
#   inflating: val/0016E5_08155.png
#   inflating: val/0016E5_08157.png
#   inflating: val/0016E5_08159.png
#    creating: valannot/
#   inflating: valannot/0016E5_07959.png
#   inflating: valannot/0016E5_07961.png
#   inflating: valannot/0016E5_07963.png
#   inflating: valannot/0016E5_07965.png
#   inflating: valannot/0016E5_07967.png
#   inflating: valannot/0016E5_07969.png
#   inflating: valannot/0016E5_07971.png
#   inflating: valannot/0016E5_07973.png
#   inflating: valannot/0016E5_07975.png
#   inflating: valannot/0016E5_07977.png
#   inflating: valannot/0016E5_07979.png
#   inflating: valannot/0016E5_07981.png
#   inflating: valannot/0016E5_07983.png
#   inflating: valannot/0016E5_07985.png
#   inflating: valannot/0016E5_07987.png
#   inflating: valannot/0016E5_07989.png
#   inflating: valannot/0016E5_07991.png
#   inflating: valannot/0016E5_07993.png
#   inflating: valannot/0016E5_07995.png
#   inflating: valannot/0016E5_07997.png
#   inflating: valannot/0016E5_07999.png
#   inflating: valannot/0016E5_08001.png
#   inflating: valannot/0016E5_08003.png
#   inflating: valannot/0016E5_08005.png
#   inflating: valannot/0016E5_08007.png
#   inflating: valannot/0016E5_08009.png
#   inflating: valannot/0016E5_08011.png
#   inflating: valannot/0016E5_08013.png
#   inflating: valannot/0016E5_08015.png
#   inflating: valannot/0016E5_08017.png
#   inflating: valannot/0016E5_08019.png
#   inflating: valannot/0016E5_08021.png
#   inflating: valannot/0016E5_08023.png
#   inflating: valannot/0016E5_08025.png
#   inflating: valannot/0016E5_08027.png
#   inflating: valannot/0016E5_08029.png
#   inflating: valannot/0016E5_08031.png
#   inflating: valannot/0016E5_08033.png
#   inflating: valannot/0016E5_08035.png
#   inflating: valannot/0016E5_08037.png
#   inflating: valannot/0016E5_08039.png
#   inflating: valannot/0016E5_08041.png
#   inflating: valannot/0016E5_08043.png
#   inflating: valannot/0016E5_08045.png
#   inflating: valannot/0016E5_08047.png
#   inflating: valannot/0016E5_08049.png
#   inflating: valannot/0016E5_08051.png
#   inflating: valannot/0016E5_08053.png
#   inflating: valannot/0016E5_08055.png
#   inflating: valannot/0016E5_08057.png
#   inflating: valannot/0016E5_08059.png
#   inflating: valannot/0016E5_08061.png
#   inflating: valannot/0016E5_08063.png
#   inflating: valannot/0016E5_08065.png
#   inflating: valannot/0016E5_08067.png
#   inflating: valannot/0016E5_08069.png
#   inflating: valannot/0016E5_08071.png
#   inflating: valannot/0016E5_08073.png
#   inflating: valannot/0016E5_08075.png
#   inflating: valannot/0016E5_08077.png
#   inflating: valannot/0016E5_08079.png
#   inflating: valannot/0016E5_08081.png
#   inflating: valannot/0016E5_08083.png
#   inflating: valannot/0016E5_08085.png
#   inflating: valannot/0016E5_08087.png
#   inflating: valannot/0016E5_08089.png
#   inflating: valannot/0016E5_08091.png
#   inflating: valannot/0016E5_08093.png
#   inflating: valannot/0016E5_08095.png
#   inflating: valannot/0016E5_08097.png
#   inflating: valannot/0016E5_08099.png
#   inflating: valannot/0016E5_08101.png
#   inflating: valannot/0016E5_08103.png
#   inflating: valannot/0016E5_08105.png
#   inflating: valannot/0016E5_08107.png
#   inflating: valannot/0016E5_08109.png
#   inflating: valannot/0016E5_08111.png
#   inflating: valannot/0016E5_08113.png
#   inflating: valannot/0016E5_08115.png
#   inflating: valannot/0016E5_08117.png
#   inflating: valannot/0016E5_08119.png
#   inflating: valannot/0016E5_08121.png
#   inflating: valannot/0016E5_08123.png
#   inflating: valannot/0016E5_08125.png
#   inflating: valannot/0016E5_08127.png
#   inflating: valannot/0016E5_08129.png
#   inflating: valannot/0016E5_08131.png
#   inflating: valannot/0016E5_08133.png
#   inflating: valannot/0016E5_08135.png
#   inflating: valannot/0016E5_08137.png
#   inflating: valannot/0016E5_08139.png
#   inflating: valannot/0016E5_08141.png
#   inflating: valannot/0016E5_08143.png
#   inflating: valannot/0016E5_08145.png
#   inflating: valannot/0016E5_08147.png
#   inflating: valannot/0016E5_08149.png
#   inflating: valannot/0016E5_08151.png
#   inflating: valannot/0016E5_08153.png
#   inflating: valannot/0016E5_08155.png
#   inflating: valannot/0016E5_08157.png
#   inflating: valannot/0016E5_08159.png

# %% [markdown]
# ## Create the ENet model
#
# We decided to to split the model to three sub classes:
#
# 1) Initial block
#
# 2) RDDNeck - class for regular, downsampling and dilated bottlenecks
#
# 3) ASNeck -  class for asymetric bottlenecks
#
# 4) UBNeck - class for upsampling bottlenecks

# %%
class InitialBlock(nn.Module):
  
  # Initial block of the model:
  #         Input
  #        /     \
  #       /       \
  #maxpool2d    conv2d-3x3
  #       \       /  
  #        \     /
  #      concatenate
   
    def __init__ (self,in_channels = 3,out_channels = 13):
        super().__init__()


        self.maxpool = nn.MaxPool2d(kernel_size=2, 
                                      stride = 2, 
                                      padding = 0)

        self.conv = nn.Conv2d(in_channels, 
                                out_channels,
                                kernel_size = 3,
                                stride = 2, 
                                padding = 1)

        self.prelu = nn.PReLU(16)

        self.batchnorm = nn.BatchNorm2d(out_channels)
  
    def forward(self, x):
        
        main = self.conv(x)
        main = self.batchnorm(main)
        
        side = self.maxpool(x)
        
        # concatenating on the channels axis
        x = torch.cat((main, side), dim=1)
        x = self.prelu(x)
        
        return x

# %%
class UBNeck(nn.Module):
    
  # Upsampling bottleneck:
  #     Bottleneck Input
  #        /        \
  #       /          \
  # conv2d-1x1     convTrans2d-1x1
  #      |             | PReLU
  #      |         convTrans2d-3x3
  #      |             | PReLU
  #      |         convTrans2d-1x1
  #      |             |
  # maxunpool2d    Regularizer
  #       \           /  
  #        \         /
  #      Summing + PReLU
  #
  #  Params: 
  #  projection_ratio - ratio between input and output channels
  #  relu - if True: relu used as the activation function else: Prelu us used
  
    def __init__(self, in_channels, out_channels, relu=False, projection_ratio=4):
        
        super().__init__()
        
        # Define class variables
        self.in_channels = in_channels
        self.reduced_depth = int(in_channels / projection_ratio)
        self.out_channels = out_channels
        
        
        if relu:
            activation = nn.ReLU()
        else:
            activation = nn.PReLU()
        
        self.unpool = nn.MaxUnpool2d(kernel_size = 2,
                                     stride = 2)
        
        self.main_conv = nn.Conv2d(in_channels = self.in_channels,
                                    out_channels = self.out_channels,
                                    kernel_size = 1)
        
        self.dropout = nn.Dropout2d(p=0.1)
        
        
        self.convt1 = nn.ConvTranspose2d(in_channels = self.in_channels,
                               out_channels = self.reduced_depth,
                               kernel_size = 1,
                               padding = 0,
                               bias = False)
        
        
        self.prelu1 = activation
        
        # This layer used for Upsampling
        self.convt2 = nn.ConvTranspose2d(in_channels = self.reduced_depth,
                                  out_channels = self.reduced_depth,
                                  kernel_size = 3,
                                  stride = 2,
                                  padding = 1,
                                  output_padding = 1,
                                  bias = False)
        
        self.prelu2 = activation
        
        self.convt3 = nn.ConvTranspose2d(in_channels = self.reduced_depth,
                                  out_channels = self.out_channels,
                                  kernel_size = 1,
                                  padding = 0,
                                  bias = False)
        
        self.prelu3 = activation
        
        self.batchnorm = nn.BatchNorm2d(self.reduced_depth)
        self.batchnorm2 = nn.BatchNorm2d(self.out_channels)
        
    def forward(self, x, indices):
        x_copy = x
        
        # Side Branch
        x = self.convt1(x)
        x = self.batchnorm(x)
        x = self.prelu1(x)
        
        x = self.convt2(x)
        x = self.batchnorm(x)
        x = self.prelu2(x)
        
        x = self.convt3(x)
        x = self.batchnorm2(x)
        
        x = self.dropout(x)
        
        # Main Branch
        
        x_copy = self.main_conv(x_copy)
        x_copy = self.unpool(x_copy, indices, output_size=x.size())
        
        # summing the main and side branches
        x = x + x_copy
        x = self.prelu3(x)
        
        return x

# %%
class RDDNeck(nn.Module):
    def __init__(self, dilation, in_channels, out_channels, down_flag, relu=False, projection_ratio=4, p=0.1):
      
  # Regular|Dilated|Downsampling bottlenecks:
  #
  #     Bottleneck Input
  #        /        \
  #       /          \
  # maxpooling2d   conv2d-1x1
  #      |             | PReLU
  #      |         conv2d-3x3
  #      |             | PReLU
  #      |         conv2d-1x1
  #      |             |
  #  Padding2d     Regularizer
  #       \           /  
  #        \         /
  #      Summing + PReLU
  #
  # Params: 
  #  dilation (bool) - if True: creating dilation bottleneck
  #  down_flag (bool) - if True: creating downsampling bottleneck
  #  projection_ratio - ratio between input and output channels
  #  relu - if True: relu used as the activation function else: Prelu us used
  #  p - dropout ratio
        
        super().__init__()
        
        # Define class variables
        self.in_channels = in_channels
        
        self.out_channels = out_channels
        self.dilation = dilation
        self.down_flag = down_flag
        
        # calculating the number of reduced channels
        if down_flag:
            self.stride = 2
            self.reduced_depth = int(in_channels // projection_ratio)
        else:
            self.stride = 1
            self.reduced_depth = int(out_channels // projection_ratio)
        
        if relu:
            activation = nn.ReLU()
        else:
            activation = nn.PReLU()
        
        self.maxpool = nn.MaxPool2d(kernel_size = 2,
                                      stride = 2,
                                      padding = 0, return_indices=True)
        

        
        self.dropout = nn.Dropout2d(p=p)

        self.conv1 = nn.Conv2d(in_channels = self.in_channels,
                               out_channels = self.reduced_depth,
                               kernel_size = 1,
                               stride = 1,
                               padding = 0,
                               bias = False,
                               dilation = 1)
        
        self.prelu1 = activation
        
        self.conv2 = nn.Conv2d(in_channels = self.reduced_depth,
                                  out_channels = self.reduced_depth,
                                  kernel_size = 3,
                                  stride = self.stride,
                                  padding = self.dilation,
                                  bias = True,
                                  dilation = self.dilation)
                                  
        self.prelu2 = activation
        
        self.conv3 = nn.Conv2d(in_channels = self.reduced_depth,
                                  out_channels = self.out_channels,
                                  kernel_size = 1,
                                  stride = 1,
                                  padding = 0,
                                  bias = False,
                                  dilation = 1)
        
        self.prelu3 = activation
        
        self.batchnorm = nn.BatchNorm2d(self.reduced_depth)
        self.batchnorm2 = nn.BatchNorm2d(self.out_channels)
        
        
    def forward(self, x):
        
        bs = x.size()[0]
        x_copy = x
        
        # Side Branch
        x = self.conv1(x)
        x = self.batchnorm(x)
        x = self.prelu1(x)
        
        x = self.conv2(x)
        x = self.batchnorm(x)
        x = self.prelu2(x)
        
        x = self.conv3(x)
        x = self.batchnorm2(x)
                
        x = self.dropout(x)
        
        # Main Branch
        if self.down_flag:
            x_copy, indices = self.maxpool(x_copy)
          
        if self.in_channels != self.out_channels:
            out_shape = self.out_channels - self.in_channels
            
            #padding and concatenating in order to match the channels axis of the side and main branches
            extras = torch.zeros((bs, out_shape, x.shape[2], x.shape[3]))
            if torch.cuda.is_available():
                extras = extras.cuda()
            x_copy = torch.cat((x_copy, extras), dim = 1)

        # Summing main and side branches
        x = x + x_copy
        x = self.prelu3(x)
        
        if self.down_flag:
            return x, indices
        else:
            return x

# %%
class ASNeck(nn.Module):
    def __init__(self, in_channels, out_channels, projection_ratio=4):
      
  # Asymetric bottleneck:
  #
  #     Bottleneck Input
  #        /        \
  #       /          \
  #      |         conv2d-1x1
  #      |             | PReLU
  #      |         conv2d-1x5
  #      |             |
  #      |         conv2d-5x1
  #      |             | PReLU
  #      |         conv2d-1x1
  #      |             |
  #  Padding2d     Regularizer
  #       \           /  
  #        \         /
  #      Summing + PReLU
  #
  # Params:    
  #  projection_ratio - ratio between input and output channels
        
        super().__init__()
        
        # Define class variables
        self.in_channels = in_channels
        self.reduced_depth = int(in_channels / projection_ratio)
        self.out_channels = out_channels
        
        self.dropout = nn.Dropout2d(p=0.1)
        
        self.conv1 = nn.Conv2d(in_channels = self.in_channels,
                               out_channels = self.reduced_depth,
                               kernel_size = 1,
                               stride = 1,
                               padding = 0,
                               bias = False)
        
        self.prelu1 = nn.PReLU()
        
        self.conv21 = nn.Conv2d(in_channels = self.reduced_depth,
                                  out_channels = self.reduced_depth,
                                  kernel_size = (1, 5),
                                  stride = 1,
                                  padding = (0, 2),
                                  bias = False)
        
        self.conv22 = nn.Conv2d(in_channels = self.reduced_depth,
                                  out_channels = self.reduced_depth,
                                  kernel_size = (5, 1),
                                  stride = 1,
                                  padding = (2, 0),
                                  bias = False)
        
        self.prelu2 = nn.PReLU()
        
        self.conv3 = nn.Conv2d(in_channels = self.reduced_depth,
                                  out_channels = self.out_channels,
                                  kernel_size = 1,
                                  stride = 1,
                                  padding = 0,
                                  bias = False)
        
        self.prelu3 = nn.PReLU()
        
        self.batchnorm = nn.BatchNorm2d(self.reduced_depth)
        self.batchnorm2 = nn.BatchNorm2d(self.out_channels)
        
    def forward(self, x):
        bs = x.size()[0]
        x_copy = x
        
        # Side Branch
        x = self.conv1(x)
        x = self.batchnorm(x)
        x = self.prelu1(x)
        
        x = self.conv21(x)
        x = self.conv22(x)
        x = self.batchnorm(x)
        x = self.prelu2(x)
        
        x = self.conv3(x)
                
        x = self.dropout(x)
        x = self.batchnorm2(x)
        
        # Main Branch
        
        if self.in_channels != self.out_channels:
            out_shape = self.out_channels - self.in_channels
            
            #padding and concatenating in order to match the channels axis of the side and main branches
            extras = torch.zeros((bs, out_shape, x.shape[2], x.shape[3]))
            if torch.cuda.is_available():
                extras = extras.cuda()
            x_copy = torch.cat((x_copy, extras), dim = 1)
        
        # Summing main and side branches
        x = x + x_copy
        x = self.prelu3(x)
        
        return x

# %%
class ENet(nn.Module):
  
  # Creating Enet model!
  
    def __init__(self, C):
        super().__init__()
        
        # Define class variables
        # C - number of classes
        self.C = C
        
        # The initial block
        self.init = InitialBlock()
        
        
        # The first bottleneck
        self.b10 = RDDNeck(dilation=1, 
                           in_channels=16, 
                           out_channels=64, 
                           down_flag=True, 
                           p=0.01)
        
        self.b11 = RDDNeck(dilation=1, 
                           in_channels=64, 
                           out_channels=64, 
                           down_flag=False, 
                           p=0.01)
        
        self.b12 = RDDNeck(dilation=1, 
                           in_channels=64, 
                           out_channels=64, 
                           down_flag=False, 
                           p=0.01)
        
        self.b13 = RDDNeck(dilation=1, 
                           in_channels=64, 
                           out_channels=64, 
                           down_flag=False, 
                           p=0.01)
        
        self.b14 = RDDNeck(dilation=1, 
                           in_channels=64, 
                           out_channels=64, 
                           down_flag=False, 
                           p=0.01)
        
        
        # The second bottleneck
        self.b20 = RDDNeck(dilation=1, 
                           in_channels=64, 
                           out_channels=128, 
                           down_flag=True)
        
        self.b21 = RDDNeck(dilation=1, 
                           in_channels=128, 
                           out_channels=128, 
                           down_flag=False)
        
        self.b22 = RDDNeck(dilation=2, 
                           in_channels=128, 
                           out_channels=128, 
                           down_flag=False)
        
        self.b23 = ASNeck(in_channels=128, 
                          out_channels=128)
        
        self.b24 = RDDNeck(dilation=4, 
                           in_channels=128, 
                           out_channels=128, 
                           down_flag=False)
        
        self.b25 = RDDNeck(dilation=1, 
                           in_channels=128, 
                           out_channels=128, 
                           down_flag=False)
        
        self.b26 = RDDNeck(dilation=8, 
                           in_channels=128, 
                           out_channels=128, 
                           down_flag=False)
        
        self.b27 = ASNeck(in_channels=128, 
                          out_channels=128)
        
        self.b28 = RDDNeck(dilation=16, 
                           in_channels=128, 
                           out_channels=128, 
                           down_flag=False)
        
        
        # The third bottleneck
        self.b31 = RDDNeck(dilation=1, 
                           in_channels=128, 
                           out_channels=128, 
                           down_flag=False)
        
        self.b32 = RDDNeck(dilation=2, 
                           in_channels=128, 
                           out_channels=128, 
                           down_flag=False)
        
        self.b33 = ASNeck(in_channels=128, 
                          out_channels=128)
        
        self.b34 = RDDNeck(dilation=4, 
                           in_channels=128, 
                           out_channels=128, 
                           down_flag=False)
        
        self.b35 = RDDNeck(dilation=1, 
                           in_channels=128, 
                           out_channels=128, 
                           down_flag=False)
        
        self.b36 = RDDNeck(dilation=8, 
                           in_channels=128, 
                           out_channels=128, 
                           down_flag=False)
        
        self.b37 = ASNeck(in_channels=128, 
                          out_channels=128)
        
        self.b38 = RDDNeck(dilation=16, 
                           in_channels=128, 
                           out_channels=128, 
                           down_flag=False)
        
        
        # The fourth bottleneck
        self.b40 = UBNeck(in_channels=128, 
                          out_channels=64, 
                          relu=True)
        
        self.b41 = RDDNeck(dilation=1, 
                           in_channels=64, 
                           out_channels=64, 
                           down_flag=False, 
                           relu=True)
        
        self.b42 = RDDNeck(dilation=1, 
                           in_channels=64, 
                           out_channels=64, 
                           down_flag=False, 
                           relu=True)
        
        
        # The fifth bottleneck
        self.b50 = UBNeck(in_channels=64, 
                          out_channels=16, 
                          relu=True)
        
        self.b51 = RDDNeck(dilation=1, 
                           in_channels=16, 
                           out_channels=16, 
                           down_flag=False, 
                           relu=True)
        
        
        # Final ConvTranspose Layer
        self.fullconv = nn.ConvTranspose2d(in_channels=16, 
                                           out_channels=self.C, 
                                           kernel_size=3, 
                                           stride=2, 
                                           padding=1, 
                                           output_padding=1,
                                           bias=False)
        
        
    def forward(self, x):
        
        # The initial block
        x = self.init(x)
        
        # The first bottleneck
        x, i1 = self.b10(x)
        x = self.b11(x)
        x = self.b12(x)
        x = self.b13(x)
        x = self.b14(x)
        
        # The second bottleneck
        x, i2 = self.b20(x)
        x = self.b21(x)
        x = self.b22(x)
        x = self.b23(x)
        x = self.b24(x)
        x = self.b25(x)
        x = self.b26(x)
        x = self.b27(x)
        x = self.b28(x)
        
        # The third bottleneck
        x = self.b31(x)
        x = self.b32(x)
        x = self.b33(x)
        x = self.b34(x)
        x = self.b35(x)
        x = self.b36(x)
        x = self.b37(x)
        x = self.b38(x)
        
        # The fourth bottleneck
        x = self.b40(x, i2)
        x = self.b41(x)
        x = self.b42(x)
        
        # The fifth bottleneck
        x = self.b50(x, i1)
        x = self.b51(x)
        
        # Final ConvTranspose Layer
        x = self.fullconv(x)
        
        return x

# %% [markdown]
# ## Instantiate the ENet model

# %%
enet = ENet(12)

# %% [markdown]
# Move the model to cuda if available

# %%
# Checking if there is any gpu available and pass the model to gpu or cpu
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
enet = enet.to(device)

# %% [markdown]
# ## Define the loader that will load the input and output images

# %%
def loader(training_path, segmented_path, batch_size, h=320, w=1000):
    filenames_t = os.listdir(training_path)
    total_files_t = len(filenames_t)
    
    filenames_s = os.listdir(segmented_path)
    total_files_s = len(filenames_s)
    
    assert(total_files_t == total_files_s)
    
    if str(batch_size).lower() == 'all':
        batch_size = total_files_s
    
    idx = 0
    while(1):
      # Choosing random indexes of images and labels
        batch_idxs = np.random.randint(0, total_files_s, batch_size)
            
        
        inputs = []
        labels = []
        
        for jj in batch_idxs:
          # Reading normalized photo
            img = plt.imread(training_path + filenames_t[jj])
          # Resizing using nearest neighbor method
            img = cv2.resize(img, (h, w), cv2.INTER_NEAREST)
            inputs.append(img)
          
          # Reading semantic image
            img = Image.open(segmented_path + filenames_s[jj])
            img = np.array(img)
          # Resizing using nearest neighbor method
            img = cv2.resize(img, (h, w), cv2.INTER_NEAREST)
            labels.append(img)
         
        inputs = np.stack(inputs, axis=2)
      # Changing image format to C x H x W
        inputs = torch.tensor(inputs).transpose(0, 2).transpose(1, 3)
        
        labels = torch.tensor(labels)
        
        yield inputs, labels

# %% [markdown]
# ## Define the class weights

# %%
def get_class_weights(num_classes, c=1.02):
    pipe = loader('/content/train/', '/content/trainannot/', batch_size='all')
    _, labels = next(pipe)
    all_labels = labels.flatten()
    each_class = np.bincount(all_labels, minlength=num_classes)
    prospensity_score = each_class / len(all_labels)
    class_weights = 1 / (np.log(c + prospensity_score))
    return class_weights

# %%
class_weights = get_class_weights(12)

# %% [markdown]
# ## Define the Hyperparameters

# %%
lr = 5e-4
batch_size = 10

criterion = nn.CrossEntropyLoss(weight=torch.FloatTensor(class_weights).to(device))
optimizer = torch.optim.Adam(enet.parameters(), 
                             lr=lr,
                             weight_decay=2e-4)

print_every = 5
eval_every = 5

# %% [markdown]
# ## Training loop

# %%
train_losses = []
eval_losses = []

bc_train = 367 // batch_size # mini_batch train
bc_eval = 101 // batch_size  # mini_batch validation

# Define pipeline objects
pipe = loader('/content/train/', '/content/trainannot/', batch_size)
eval_pipe = loader('/content/val/', '/content/valannot/', batch_size)

epochs = 100

# Train loop

for e in range(1, epochs+1):
    
    
    train_loss = 0
    print ('-'*15,'Epoch %d' % e, '-'*15)
    
    enet.train()
    
    for _ in tqdm(range(bc_train)):
        X_batch, mask_batch = next(pipe)
        
        # assign data to cpu/gpu
        X_batch, mask_batch = X_batch.to(device), mask_batch.to(device)

        optimizer.zero_grad()

        out = enet(X_batch.float())
        
        # loss calculation
        loss = criterion(out, mask_batch.long())
        # update weights
        loss.backward()
        optimizer.step()

        train_loss += loss.item()

        
    print ()
    train_losses.append(train_loss)
    
    if (e+1) % print_every == 0:
        print ('Epoch {}/{}...'.format(e, epochs),
                'Loss {:6f}'.format(train_loss))
    
    if e % eval_every == 0:
        with torch.no_grad():
            enet.eval()
            
            eval_loss = 0

            # Validation loop
            for _ in tqdm(range(bc_eval)):
                inputs, labels = next(eval_pipe)

                
                inputs, labels = inputs.to(device), labels.to(device)
                    
                
                out = enet(inputs)
                
                out = out.data.max(1)[1]
                
                eval_loss += (labels.long() - out.long()).sum()
                
            
            print ()
            print ('Loss {:6f}'.format(eval_loss))
            
            eval_losses.append(eval_loss)
        
    if e % print_every == 0:
        checkpoint = {
            'epochs' : e,
            'state_dict' : enet.state_dict()
        }
        torch.save(checkpoint, '/content/ckpt-enet-{}-{}.pth'.format(e, train_loss))
        print ('Model saved!')

print ('Epoch {}/{}...'.format(e, epochs),
       'Total Mean Loss: {:6f}'.format(sum(train_losses) / epochs))
# Out:
#   0%|          | 0/36 [00:00<?, ?it/s]
# --------------- Epoch 1 ---------------
# 100%|██████████| 36/36 [00:53<00:00,  1.46s/it]
# Epoch 2/1... Total Mean Loss: 87.405855

# %% [markdown]
# ## Infer using the trained model

# %% [markdown]
# Get the PreTrained ENet model

# %%
# !wget https://github.com/iArunava/ENet-Real-Time-Semantic-Segmentation/raw/master/datasets/CamVid/ckpt-enet.pth
# Out:
# --2019-02-11 05:52:16--  https://github.com/iArunava/ENet-Real-Time-Semantic-Segmentation/raw/master/datasets/CamVid/ckpt-enet.pth
# Resolving github.com (github.com)... 192.30.253.112, 192.30.253.113
# Connecting to github.com (github.com)|192.30.253.112|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/iArunava/ENet-Real-Time-Semantic-Segmentation/master/datasets/CamVid/ckpt-enet.pth [following]
# --2019-02-11 05:52:16--  https://raw.githubusercontent.com/iArunava/ENet-Real-Time-Semantic-Segmentation/master/datasets/CamVid/ckpt-enet.pth
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1515928 (1.4M) [application/octet-stream]
# Saving to: ‘ckpt-enet.pth’
#
# ckpt-enet.pth       100%[===================>]   1.45M  --.-KB/s    in 0.06s
#
# 2019-02-11 05:52:17 (23.1 MB/s) - ‘ckpt-enet.pth’ saved [1515928/1515928]

# %% [markdown]
# Load the ENet model

# %%
# Load a pretrained model if needed
enet = ENet(12)
state_dict = torch.load('/content/ckpt-enet.pth')['state_dict']
enet.load_state_dict(state_dict)

# %% [markdown]
# ## Use the code to infer on new images

# %%
fname = 'Seq05VD_f05100.png'
tmg_ = plt.imread('/content/test/' + fname)
tmg_ = cv2.resize(tmg_, (512, 512), cv2.INTER_NEAREST)
tmg = torch.tensor(tmg_).unsqueeze(0).float()
tmg = tmg.transpose(2, 3).transpose(1, 2).to(device)

enet.to(device)
with torch.no_grad():
    out1 = enet(tmg.float()).squeeze(0)

# %% [markdown]
# ## Load the label image

# %%
smg_ = Image.open('/content/testannot/' + fname)
smg_ = cv2.resize(np.array(smg_), (512, 512), cv2.INTER_NEAREST)

# %% [markdown]
# ## Move the output to cpu and convert it to numpy and see how each class looks

# %%
out2 = out1.cpu().detach().numpy()

# %%
mno = 8 # Should be between 0 - n-1 | where n is the number of classes

figure = plt.figure(figsize=(20, 10))
plt.subplot(1, 3, 1)
plt.title('Input Image')
plt.axis('off')
plt.imshow(tmg_)
plt.subplot(1, 3, 2)
plt.title('Output Image')
plt.axis('off')
plt.imshow(out2[mno, :, :])
plt.show()

# %% [markdown]
# Get the class labels from the output

# %%
b_ = out1.data.max(0)[1].cpu().numpy()

# %% [markdown]
# Define the function that maps a 2D image with all the class labels to a segmented image with the specified colored maps

# %%
def decode_segmap(image):
    Sky = [128, 128, 128]
    Building = [128, 0, 0]
    Pole = [192, 192, 128]
    Road_marking = [255, 69, 0]
    Road = [128, 64, 128]
    Pavement = [60, 40, 222]
    Tree = [128, 128, 0]
    SignSymbol = [192, 128, 128]
    Fence = [64, 64, 128]
    Car = [64, 0, 128]
    Pedestrian = [64, 64, 0]
    Bicyclist = [0, 128, 192]

    label_colours = np.array([Sky, Building, Pole, Road_marking, Road, 
                              Pavement, Tree, SignSymbol, Fence, Car, 
                              Pedestrian, Bicyclist]).astype(np.uint8)
    r = np.zeros_like(image).astype(np.uint8)
    g = np.zeros_like(image).astype(np.uint8)
    b = np.zeros_like(image).astype(np.uint8)
    for l in range(0, 12):
        r[image == l] = label_colours[l, 0]
        g[image == l] = label_colours[l, 1]
        b[image == l] = label_colours[l, 2]

    rgb = np.zeros((image.shape[0], image.shape[1], 3)).astype(np.uint8)
    rgb[:, :, 0] = b
    rgb[:, :, 1] = g
    rgb[:, :, 2] = r
    return rgb

# %% [markdown]
# Decode the images

# %%
true_seg = decode_segmap(smg_)
pred_seg = decode_segmap(b_)

# %%
figure = plt.figure(figsize=(20, 10))
plt.subplot(1, 3, 1)
plt.title('Input Image')
plt.axis('off')
plt.imshow(tmg_)
plt.subplot(1, 3, 2)
plt.title('Predicted Segmentation')
plt.axis('off')
plt.imshow(pred_seg)
plt.subplot(1, 3, 3)
plt.title('Ground Truth')
plt.axis('off')
plt.imshow(true_seg)
plt.show()

# %% [markdown]
# ## Save the model checkpoint

# %%
# Save the parameters
checkpoint = {
    'epochs' : e,
    'state_dict' : enet.state_dict()
}
torch.save(checkpoint, 'ckpt-enet-1.pth')

# %% [markdown]
# ## Save the entire model

# %%
# Save the model
torch.save(enet, '/content/model.pt')
